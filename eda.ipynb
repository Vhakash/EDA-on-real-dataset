# %% [markdown]
# <a href="https://colab.research.google.com/github/Vhakash/EDA-on-real-dataset/blob/main/eda.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Exploratory Data Analysis**

# %% [markdown]
# This code cell loads the various CSV datasets into pandas DataFrames. Each DataFrame corresponds to a different aspect of the e-commerce data, such as customer information, order details, products, sellers, payments, reviews, and product category translations.

# %%
import pandas as pd

# Define the path to the dataset directory
path = '/content/daata'

# Load the datasets
customers_df = pd.read_csv(f'{path}/olist_customers_dataset.csv')
orders_df = pd.read_csv(f'{path}/olist_orders_dataset.csv')
order_items_df = pd.read_csv(f'{path}/olist_order_items_dataset.csv')
products_df = pd.read_csv(f'{path}/olist_products_dataset.csv')
sellers_df = pd.read_csv(f'{path}/olist_sellers_dataset.csv')
order_payments_df = pd.read_csv(f'{path}/olist_order_payments_dataset.csv')
order_reviews_df = pd.read_csv(f'{path}/olist_order_reviews_dataset.csv')
product_category_translation_df = pd.read_csv(f'{path}/product_category_name_translation.csv')

print("All datasets loaded successfully.")
# Out:
# All datasets loaded successfully.

# %% [markdown]
# This cell provides an initial overview of the `customers_df` DataFrame. It displays the first 5 rows using `.head()`, shows concise information about the DataFrame including column names, non-null counts, and data types using `.info()`, and calculates the number of missing values for each column using `.isnull().sum()`.

# %%
print("Overview of customers_df:")
display(customers_df.head())
print(customers_df.info())
print("\nMissing values in customers_df:")
print(customers_df.isnull().sum())
# Out:
# Overview of customers_df:
#                         customer_id                customer_unique_id  \
# 0  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1  18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2  4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3  b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4  4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
#
#    customer_zip_code_prefix          customer_city customer_state
# 0                     14409                 franca             SP
# 1                      9790  sao bernardo do campo             SP
# 2                      1151              sao paulo             SP
# 3                      8775        mogi das cruzes             SP
# 4                     13056               campinas             SP
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 5 columns):
# ...

# %% [markdown]
# This cell provides an initial overview of the `orders_df` DataFrame. It displays the first 5 rows using `.head()`, shows concise information about the DataFrame including column names, non-null counts, and data types using `.info()`, and calculates the number of missing values for each column using `.isnull().sum()`.

# %%
print("\nOverview of orders_df:")
display(orders_df.head())
print(orders_df.info())
print("\nMissing values in orders_df:")
print(orders_df.isnull().sum())
# Out:
# Overview of orders_df:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3  949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4  ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
#
#   order_status order_purchase_timestamp    order_approved_at  \
# 0    delivered      2017-10-02 10:56:33  2017-10-02 11:07:15
# 1    delivered      2018-07-24 20:41:37  2018-07-26 03:24:27
# 2    delivered      2018-08-08 08:38:49  2018-08-08 08:55:23
# 3    delivered      2017-11-18 19:28:06  2017-11-18 19:45:59
# 4    delivered      2018-02-13 21:18:39  2018-02-13 22:20:29
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0          2017-10-04 19:55:00           2017-10-10 21:25:13
# ...

# %% [markdown]
# This cell provides an initial overview of the `order_items_df` DataFrame. It displays the first 5 rows using `.head()`, shows concise information about the DataFrame including column names, non-null counts, and data types using `.info()`, and calculates the number of missing values for each column using `.isnull().sum()`.

# %%
print("\nOverview of order_items_df:")
display(order_items_df.head())
print(order_items_df.info())
print("\nMissing values in order_items_df:")
print(order_items_df.isnull().sum())
# Out:
# Overview of order_items_df:
#                            order_id  order_item_id  \
# 0  00010242fe8c5a6d1ba2dd792cb16214              1
# 1  00018f77f2f0320c557190d7a144bdd3              1
# 2  000229ec398224ef6ca0657da4fc703e              1
# 3  00024acbcdf0a6daa1e931b038114c75              1
# 4  00042b26cf59d7ce69dfabb4e55b4fd9              1
#
#                          product_id                         seller_id  \
# 0  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1  e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# 2  c777355d18b72b67abbeef9df44fd0fd  5b51032eddd242adc84c38acab88f23d
# 3  7634da152a4610f1595efa32f14722fc  9d7a1d34a5052409006425275ba1c2b4
# 4  ac6c3623068f30de03045865e4e10089  df560393f3a51e74553ab94004ba5c87
#
#    shipping_limit_date   price  freight_value
# 0  2017-09-19 09:45:35   58.90          13.29
# 1  2017-05-03 11:05:13  239.90          19.93
# 2  2018-01-18 14:48:30  199.00          17.87
# ...

# %% [markdown]
# This cell provides an initial overview of the `products_df` DataFrame. It displays the first 5 rows using `.head()`, shows concise information about the DataFrame including column names, non-null counts, and data types using `.info()`, and calculates the number of missing values for each column using `.isnull().sum()`.

# %%
print("\nOverview of products_df:")
display(products_df.head())
print(products_df.info())
print("\nMissing values in products_df:")
print(products_df.isnull().sum())
# Out:
# Overview of products_df:
#                          product_id  product_category_name  \
# 0  1e9e8ef04dbcff4541ed26657ea517e5             perfumaria
# 1  3aa071139cb16b67ca9e5dea641aaa2f                  artes
# 2  96bd76ec8810374ed1b65e291975717f          esporte_lazer
# 3  cef67bcfe19066a932b7673e239eb23d                  bebes
# 4  9dc1a7de274444849c219cff195d0b71  utilidades_domesticas
#
#    product_name_lenght  product_description_lenght  product_photos_qty  \
# 0                 40.0                       287.0                 1.0
# 1                 44.0                       276.0                 1.0
# 2                 46.0                       250.0                 1.0
# 3                 27.0                       261.0                 1.0
# 4                 37.0                       402.0                 4.0
#
#    product_weight_g  product_length_cm  product_height_cm  product_width_cm
# 0             225.0               16.0               10.0              14.0
# ...

# %% [markdown]
# This cell provides an initial overview of the `sellers_df` DataFrame. It displays the first 5 rows using `.head()`, shows concise information about the DataFrame including column names, non-null counts, and data types using `.info()`, and calculates the number of missing values for each column using `.isnull().sum()`.

# %%
print("\nOverview of sellers_df:")
display(sellers_df.head())
print(sellers_df.info())
print("\nMissing values in sellers_df:")
print(sellers_df.isnull().sum())
# Out:
# Overview of sellers_df:
#                           seller_id  seller_zip_code_prefix  \
# 0  3442f8959a84dea7ee197c632cb2df15                   13023
# 1  d1b65fc7debc3361ea86b5f14c68d2e2                   13844
# 2  ce3ad9de960102d0677a81f5d0bb7b2d                   20031
# 3  c0f3eea2e14555b6faeea3dd58c1b1c3                    4195
# 4  51a04a8a6bdcb23deccc82b0b80742cf                   12914
#
#          seller_city seller_state
# 0           campinas           SP
# 1         mogi guacu           SP
# 2     rio de janeiro           RJ
# 3          sao paulo           SP
# 4  braganca paulista           SP
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3095 entries, 0 to 3094
# Data columns (total 4 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   seller_id               3095 non-null   object
#  1   seller_zip_code_prefix  3095 non-null   int64
#  2   seller_city             3095 non-null   object
# ...

# %% [markdown]
# This cell provides an initial overview of the `order_payments_df` DataFrame. It displays the first 5 rows using `.head()`, shows concise information about the DataFrame including column names, non-null counts, and data types using `.info()`, and calculates the number of missing values for each column using `.isnull().sum()`.

# %%
print("\nOverview of order_payments_df:")
display(order_payments_df.head())
print(order_payments_df.info())
print("\nMissing values in order_payments_df:")
print(order_payments_df.isnull().sum())
# Out:
# Overview of order_payments_df:
#                            order_id  payment_sequential payment_type  \
# 0  b81ef226f3fe1789b1e8b2acac839d17                   1  credit_card
# 1  a9810da82917af2d9aefd1278f1dcfa0                   1  credit_card
# 2  25e8ea4e93396b6fa0d3dd708e76c1bd                   1  credit_card
# 3  ba78997921bbcdc1373bb41e913ab953                   1  credit_card
# 4  42fdf880ba16b47b59251dd489d4441a                   1  credit_card
#
#    payment_installments  payment_value
# 0                     8          99.33
# 1                     1          24.39
# 2                     1          65.71
# 3                     8         107.78
# 4                     2         128.45
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103886 entries, 0 to 103885
# Data columns (total 5 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   order_id              103886 non-null  object
# ...

# %% [markdown]
# This cell provides an initial overview of the `order_reviews_df` DataFrame. It displays the first 5 rows using `.head()`, shows concise information about the DataFrame including column names, non-null counts, and data types using `.info()`, and calculates the number of missing values for each column using `.isnull().sum()`.

# %%
print("\nOverview of order_reviews_df:")
display(order_reviews_df.head())
print(order_reviews_df.info())
print("\nMissing values in order_reviews_df:")
print(order_reviews_df.isnull().sum())
# Out:
# Overview of order_reviews_df:
#                           review_id                          order_id  \
# 0  7bc2406110b926393aa56f80a40eba40  73fc7af87114b39712e6da79b0a377eb
# 1  80e641a11e56f04c1ad469d5645fdfde  a548910a1c6147796b98fdf73dbeba33
# 2  228ce5500dc1d8e020d8d1322874b6f0  f9e4b658b201a9f2ecdecbb34bed034b
# 3  e64fb393e7b32834bb789ff8bb30750e  658677c97b385a9be170737859d3511b
# 4  f7c4243c7fe1938f181bec41a392bdeb  8e6bfb81e283fa7e4f11123a3fb894f1
#
#    review_score review_comment_title  \
# 0             4                  NaN
# 1             5                  NaN
# 2             5                  NaN
# 3             5                  NaN
# 4             5                  NaN
#
#                               review_comment_message review_creation_date  \
# 0                                                NaN  2018-01-18 00:00:00
# 1                                                NaN  2018-03-10 00:00:00
# ...

# %% [markdown]
# This cell provides an initial overview of the `product_category_translation_df` DataFrame. It displays the first 5 rows using `.head()`, shows concise information about the DataFrame including column names, non-null counts, and data types using `.info()`, and calculates the number of missing values for each column using `.isnull().sum()`.

# %%
print("\nOverview of product_category_translation_df:")
display(product_category_translation_df.head())
print(product_category_translation_df.info())
print("\nMissing values in product_category_translation_df:")
print(product_category_translation_df.isnull().sum())
# Out:
# Overview of product_category_translation_df:
#     product_category_name product_category_name_english
# 0            beleza_saude                 health_beauty
# 1  informatica_acessorios         computers_accessories
# 2              automotivo                          auto
# 3         cama_mesa_banho                bed_bath_table
# 4        moveis_decoracao               furniture_decor
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 71 entries, 0 to 70
# Data columns (total 2 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   product_category_name          71 non-null     object
#  1   product_category_name_english  71 non-null     object
# dtypes: object(2)
# memory usage: 1.2+ KB
# None
#
# Missing values in product_category_translation_df:
# product_category_name            0
# product_category_name_english    0
# dtype: int64

# %% [markdown]
# # MERGING RELATED COLUMNS

# %% [markdown]
# This cell merges the `orders_df` and `customers_df` DataFrames on the `customer_id` column. It then displays the first 5 rows of the resulting merged DataFrame.

# %%
# Merge orders and customers dataframes
orders_customers_df = pd.merge(orders_df, customers_df, on='customer_id', how='left')

print("\nMerged orders_df and customers_df:")
display(orders_customers_df.head())
# Out:
# Merged orders_df and customers_df:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3  949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4  ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
#
#   order_status order_purchase_timestamp    order_approved_at  \
# 0    delivered      2017-10-02 10:56:33  2017-10-02 11:07:15
# 1    delivered      2018-07-24 20:41:37  2018-07-26 03:24:27
# 2    delivered      2018-08-08 08:38:49  2018-08-08 08:55:23
# 3    delivered      2017-11-18 19:28:06  2017-11-18 19:45:59
# 4    delivered      2018-02-13 21:18:39  2018-02-13 22:20:29
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0          2017-10-04 19:55:00           2017-10-10 21:25:13
# ...

# %% [markdown]
# This cell merges the `order_items_df` and `products_df` DataFrames on the `product_id` column. It then displays the first 5 rows of the resulting merged DataFrame.

# %%
# Merge order_items and products dataframes
order_items_products_df = pd.merge(order_items_df, products_df, on='product_id', how='left')

print("\nMerged order_items_df and products_df:")
display(order_items_products_df.head())
# Out:
# Merged order_items_df and products_df:
#                            order_id  order_item_id  \
# 0  00010242fe8c5a6d1ba2dd792cb16214              1
# 1  00018f77f2f0320c557190d7a144bdd3              1
# 2  000229ec398224ef6ca0657da4fc703e              1
# 3  00024acbcdf0a6daa1e931b038114c75              1
# 4  00042b26cf59d7ce69dfabb4e55b4fd9              1
#
#                          product_id                         seller_id  \
# 0  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1  e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# 2  c777355d18b72b67abbeef9df44fd0fd  5b51032eddd242adc84c38acab88f23d
# 3  7634da152a4610f1595efa32f14722fc  9d7a1d34a5052409006425275ba1c2b4
# 4  ac6c3623068f30de03045865e4e10089  df560393f3a51e74553ab94004ba5c87
#
#    shipping_limit_date   price  freight_value product_category_name  \
# 0  2017-09-19 09:45:35   58.90          13.29            cool_stuff
# ...

# %% [markdown]
# This cell merges the `order_items_products_df` (which contains order item and product information) and `sellers_df` DataFrames on the `seller_id` column. It then displays the first 5 rows of the resulting merged DataFrame.

# %%
# Merge order_items_products and sellers dataframes
order_items_products_sellers_df = pd.merge(order_items_products_df, sellers_df, on='seller_id', how='left')

print("\nMerged order_items_products_df and sellers_df:")
display(order_items_products_sellers_df.head())
# Out:
# Merged order_items_products_df and sellers_df:
#                            order_id  order_item_id  \
# 0  00010242fe8c5a6d1ba2dd792cb16214              1
# 1  00018f77f2f0320c557190d7a144bdd3              1
# 2  000229ec398224ef6ca0657da4fc703e              1
# 3  00024acbcdf0a6daa1e931b038114c75              1
# 4  00042b26cf59d7ce69dfabb4e55b4fd9              1
#
#                          product_id                         seller_id  \
# 0  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1  e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# 2  c777355d18b72b67abbeef9df44fd0fd  5b51032eddd242adc84c38acab88f23d
# 3  7634da152a4610f1595efa32f14722fc  9d7a1d34a5052409006425275ba1c2b4
# 4  ac6c3623068f30de03045865e4e10089  df560393f3a51e74553ab94004ba5c87
#
#    shipping_limit_date   price  freight_value product_category_name  \
# 0  2017-09-19 09:45:35   58.90          13.29            cool_stuff
# ...

# %% [markdown]
# This cell merges the `orders_customers_df` (which contains order and customer information) and `order_payments_df` DataFrames on the `order_id` column. It then displays the first 5 rows of the resulting merged DataFrame.

# %%
# Merge orders_customers and order_payments dataframes
orders_customers_payments_df = pd.merge(orders_customers_df, order_payments_df, on='order_id', how='left')

print("\nMerged orders_customers_df and order_payments_df:")
display(orders_customers_payments_df.head())
# Out:
# Merged orders_customers_df and order_payments_df:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 2  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 3  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 4  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
#
#   order_status order_purchase_timestamp    order_approved_at  \
# 0    delivered      2017-10-02 10:56:33  2017-10-02 11:07:15
# 1    delivered      2017-10-02 10:56:33  2017-10-02 11:07:15
# 2    delivered      2017-10-02 10:56:33  2017-10-02 11:07:15
# 3    delivered      2018-07-24 20:41:37  2018-07-26 03:24:27
# 4    delivered      2018-08-08 08:38:49  2018-08-08 08:55:23
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# ...

# %% [markdown]
# This cell merges the `orders_customers_df` (which contains order and customer information) and `order_reviews_df` DataFrames on the `order_id` column. It then displays the first 5 rows of the resulting merged DataFrame.

# %%
# Merge orders_customers and order_reviews dataframes
orders_customers_reviews_df = pd.merge(orders_customers_df, order_reviews_df, on='order_id', how='left')

print("\nMerged orders_customers_df and order_reviews_df:")
display(orders_customers_reviews_df.head())
# Out:
# Merged orders_customers_df and order_reviews_df:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3  949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4  ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
#
#   order_status order_purchase_timestamp    order_approved_at  \
# 0    delivered      2017-10-02 10:56:33  2017-10-02 11:07:15
# 1    delivered      2018-07-24 20:41:37  2018-07-26 03:24:27
# 2    delivered      2018-08-08 08:38:49  2018-08-08 08:55:23
# 3    delivered      2017-11-18 19:28:06  2017-11-18 19:45:59
# 4    delivered      2018-02-13 21:18:39  2018-02-13 22:20:29
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0          2017-10-04 19:55:00           2017-10-10 21:25:13
# ...

# %% [markdown]
# This cell merges the `order_items_products_df` (which contains order item and product information) and `product_category_translation_df` DataFrames on the `product_category_name` column. It then displays the first 5 rows of the resulting merged DataFrame.

# %%
# Merge order_items_products and product_category_translation dataframes
order_items_products_translated_df = pd.merge(order_items_products_df, product_category_translation_df, on='product_category_name', how='left')

print("\nMerged order_items_products_df and product_category_translation_df:")
display(order_items_products_translated_df.head())
# Out:
# Merged order_items_products_df and product_category_translation_df:
#                            order_id  order_item_id  \
# 0  00010242fe8c5a6d1ba2dd792cb16214              1
# 1  00018f77f2f0320c557190d7a144bdd3              1
# 2  000229ec398224ef6ca0657da4fc703e              1
# 3  00024acbcdf0a6daa1e931b038114c75              1
# 4  00042b26cf59d7ce69dfabb4e55b4fd9              1
#
#                          product_id                         seller_id  \
# 0  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1  e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# 2  c777355d18b72b67abbeef9df44fd0fd  5b51032eddd242adc84c38acab88f23d
# 3  7634da152a4610f1595efa32f14722fc  9d7a1d34a5052409006425275ba1c2b4
# 4  ac6c3623068f30de03045865e4e10089  df560393f3a51e74553ab94004ba5c87
#
#    shipping_limit_date   price  freight_value product_category_name  \
# 0  2017-09-19 09:45:35   58.90          13.29            cool_stuff
# ...

# %% [markdown]
# # Visualizing the **Data**

# %% [markdown]
# This cell visualizes the distribution of `review_score` in the `orders_customers_reviews_df` DataFrame using a bar plot.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(8, 6))
sns.countplot(data=orders_customers_reviews_df, x='review_score')
plt.title('Distribution of Review Scores')
plt.xlabel('Review Score')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# This cell visualizes the distribution of `payment_type` in the `orders_customers_payments_df` DataFrame using a bar plot.

# %%
plt.figure(figsize=(10, 6))
sns.countplot(data=orders_customers_payments_df, y='payment_type', order = orders_customers_payments_df['payment_type'].value_counts().index)
plt.title('Distribution of Payment Types')
plt.xlabel('Count')
plt.ylabel('Payment Type')
plt.show()

# %% [markdown]
# This cell visualizes the distribution of `order_status` in the `orders_df` DataFrame using a bar plot.

# %%
plt.figure(figsize=(10, 6))
sns.countplot(data=orders_df, y='order_status', order = orders_df['order_status'].value_counts().index)
plt.title('Distribution of Order Status')
plt.xlabel('Count')
plt.ylabel('Order Status')
plt.show()

# %% [markdown]
# This cell visualizes the top 10 product categories by count in the `order_items_products_translated_df` DataFrame using a bar plot.

# %%
plt.figure(figsize=(12, 6))
sns.countplot(data=order_items_products_translated_df, y='product_category_name_english', order=order_items_products_translated_df['product_category_name_english'].value_counts().nlargest(10).index)
plt.title('Top 10 Product Categories')
plt.xlabel('Count')
plt.ylabel('Product Category')
plt.show()

# %% [markdown]
# # Task
# Summarize the EDA process performed on the Brazilian Commerce dataset, highlight key findings, and provide a concluding statement.

# %% [markdown]
# ## Summarize eda process
#
# ### Subtask:
# Briefly reiterate the steps taken during the exploratory data analysis.

# %% [markdown]
# **Reasoning**:
# Summarize the EDA steps as requested in the instructions.

# %%
print("Summary of the EDA Process:")

# 1. Initial Data Loading
print("\n1. Initial Data Loading:")
print("Multiple CSV files were loaded into separate pandas DataFrames: customers_df, orders_df, order_items_df, products_df, sellers_df, order_payments_df, order_reviews_df, and product_category_translation_df.")

# 2. Initial Data Overview
print("\n2. Initial Data Overview:")
print("For each loaded DataFrame, the following steps were performed:")
print("   - Displaying the first 5 rows using `.head()`.")
print("   - Checking concise information including column names, non-null counts, and data types using `.info()`.")
print("   - Calculating the number of missing values for each column using `.isnull().sum()`.")

# 3. Data Merging
print("\n3. Data Merging:")
print("Several DataFrames were merged to combine related information:")
print("   - `orders_df` and `customers_df` were merged on `customer_id`.")
print("   - `order_items_df` and `products_df` were merged on `product_id`.")
print("   - The merged `order_items_products_df` and `sellers_df` were merged on `seller_id`.")
print("   - `orders_customers_df` and `order_payments_df` were merged on `order_id`.")
print("   - `orders_customers_df` and `order_reviews_df` were merged on `order_id`.")
print("   - `order_items_products_df` and `product_category_translation_df` were merged on `product_category_name`.")


# 4. Data Visualization
print("\n4. Data Visualization:")
print("Visualizations were created to understand the distribution of key variables:")
print("   - Bar plot showing the distribution of `review_score`.")
print("   - Bar plot showing the distribution of `payment_type`.")
print("   - Bar plot showing the distribution of `order_status`.")
print("   - Bar plot showing the top 10 `product_category_name_english`.")
# Out:
# Summary of the EDA Process:
#
# 1. Initial Data Loading:
# Multiple CSV files were loaded into separate pandas DataFrames: customers_df, orders_df, order_items_df, products_df, sellers_df, order_payments_df, order_reviews_df, and product_category_translation_df.
#
# 2. Initial Data Overview:
# For each loaded DataFrame, the following steps were performed:
#    - Displaying the first 5 rows using `.head()`.
#    - Checking concise information including column names, non-null counts, and data types using `.info()`.
#    - Calculating the number of missing values for each column using `.isnull().sum()`.
#
# 3. Data Merging:
# Several DataFrames were merged to combine related information:
#    - `orders_df` and `customers_df` were merged on `customer_id`.
#    - `order_items_df` and `products_df` were merged on `product_id`.
#    - The merged `order_items_products_df` and `sellers_df` were merged on `seller_id`.
# ...

# %% [markdown]
# ## Highlight key findings
#
# ### Subtask:
# Present the significant observations and insights gained from the data overview, descriptive statistics, and visualizations.

# %% [markdown]
# **Reasoning**:
# Synthesize the observations from the initial data overviews, visualizations, and data merging steps to highlight the key findings of the EDA.

# %%
print("Key Findings from EDA:")

# Findings from Data Overview
print("\nFindings from Data Overview:")
print("- `customers_df`: Contains customer information, no missing values.")
print("- `orders_df`: Contains order details, with missing values in `order_approved_at`, `order_delivered_carrier_date`, and `order_delivered_customer_date`.")
print("- `order_items_df`: Contains order item details, no missing values.")
print("- `products_df`: Contains product information, with missing values in `product_category_name`, `product_name_lenght`, `product_description_lenght`, `product_photos_qty`, `product_weight_g`, `product_length_cm`, `product_height_cm`, and `product_width_cm`.")
print("- `sellers_df`: Contains seller information, no missing values.")
print("- `order_payments_df`: Contains order payment information, no missing values.")
print("- `order_reviews_df`: Contains order review information, with significant missing values in `review_comment_title` and `review_comment_message`.")
print("- `product_category_translation_df`: Contains product category name translations, no missing values.")

# Findings from Visualizations
print("\nFindings from Visualizations:")
print("- Review Scores: The distribution of review scores is heavily skewed towards higher scores (4 and 5), indicating generally positive customer feedback.")
print("- Payment Types: Credit card is the most frequent payment type, followed by boleto, voucher, and debit card.")
print("- Order Status: The vast majority of orders have a 'delivered' status, with a small percentage in other statuses like 'shipped', 'canceled', and 'unavailable'.")
print("- Top 10 Product Categories: The top product categories by number of orders are 'bed_bath_table', 'health_beauty', and 'sports_leisure'.")

# Findings from Data Merging
print("\nFindings from Data Merging:")
print("- Merging `orders_df` and `customers_df` provides a combined view of order and customer information, linking orders to unique customers and their location.")
print("- Merging `order_items_df` and `products_df` allows for analysis of products within orders, including product details and categories.")
print("- Merging `order_items_products_df` and `sellers_df` connects order items to seller information, enabling analysis of seller performance and location.")
print("- Merging `orders_customers_df` and `order_payments_df` combines order and customer data with payment details, facilitating analysis of payment methods and values per order and customer.")
print("- Merging `orders_customers_df` and `order_reviews_df` integrates order and customer data with review information, allowing for analysis of customer satisfaction based on orders.")
print("- Merging `order_items_products_df` and `product_category_translation_df` adds English translations to product categories, making category analysis more accessible.")

# Synthesized Summary
print("\nSynthesized Summary:")
print("The EDA revealed a large dataset with generally positive customer reviews and a dominance of credit card payments. Most orders are successfully delivered. There are notable missing values in order delivery dates and product details, as well as review comments. The merging process successfully integrated various aspects of the e-commerce data, creating comprehensive DataFrames for further analysis, particularly allowing for insights into customer behavior, product popularity, and seller activity across different dimensions like location and payment methods.")
# Out:
# Key Findings from EDA:
#
# Findings from Data Overview:
# - `customers_df`: Contains customer information, no missing values.
# - `orders_df`: Contains order details, with missing values in `order_approved_at`, `order_delivered_carrier_date`, and `order_delivered_customer_date`.
# - `order_items_df`: Contains order item details, no missing values.
# - `products_df`: Contains product information, with missing values in `product_category_name`, `product_name_lenght`, `product_description_lenght`, `product_photos_qty`, `product_weight_g`, `product_length_cm`, `product_height_cm`, and `product_width_cm`.
# - `sellers_df`: Contains seller information, no missing values.
# - `order_payments_df`: Contains order payment information, no missing values.
# - `order_reviews_df`: Contains order review information, with significant missing values in `review_comment_title` and `review_comment_message`.
# ...

# %% [markdown]
# ## Summary:
#
# ### Data Analysis Key Findings
#
# *   **Missing Values:** The `orders_df` has missing values in columns related to delivery dates (`order_approved_at`, `order_delivered_carrier_date`, `order_delivered_customer_date`). The `products_df` has missing values in `product_category_name` and several product dimension/weight columns. The `order_reviews_df` has significant missing values in `review_comment_title` and `review_comment_message`.
# *   **Review Scores:** Customer reviews are predominantly positive, with a high frequency of scores 4 and 5.
# *   **Payment Types:** Credit card is the most frequently used payment method, followed by boleto, voucher, and debit card.
# *   **Order Status:** The vast majority of orders have reached a 'delivered' status.
# *   **Top Product Categories:** The leading product categories in terms of order volume are 'bed\_bath\_table', 'health\_beauty', and 'sports\_leisure'.
#
# ### Insights or Next Steps
#
# *   Further analysis could focus on handling the missing values, particularly in delivery dates and product details, to ensure data completeness for more advanced modeling or analysis.
# *   Investigate the relationship between review scores, payment types, and order status to understand factors influencing customer satisfaction and delivery success.
